# %%
from __future__ import annotations

import pandas as pd
import json
from pathlib import Path
from typing import Any, Dict, List

# %%
def get_item_data(json_file='items.json'):
    
    # Load JSON file
    with open(json_file, 'r', encoding='utf8') as file:
        item_data = json.load(file)

    # Get all item effects (healing, reccharging, etc...):
    effect_set = {
        k
        for item in item_data
        if isinstance(item.get('effects'), dict)
        for k in item['effects']
    }
    effect_list = list(effect_set)

    # Clean list
    item_list = []
    for item in item_data:
        new_dict = {}
        for k, v in item.items():
            if isinstance(v, dict) and 'en' in v:
                new_dict[k] = v['en']
            elif k == 'effects':
                new_dict[k] = []
                effect_dict = {}
                for effect in effect_list:
                    if effect in v:
                        effect_dict[effect] =v[effect]['value']
                new_dict[k].append(effect_dict)
            else:
                new_dict[k] = v
        item_list.append(new_dict)

    return item_list

def get_quest_data(json_file='quests.json'):
        
    # Load JSON file
    with open(json_file, 'r', encoding='utf8') as file:
        quest_data = json.load(file)

    # get all quests
    quest_list = []
    for item in quest_data:
        new_dict = {}
        for k, v in item.items():
            if isinstance(v, dict) and 'en' in v:
                new_dict[k] = v['en']
            elif k == 'objectives':
                new_dict[k] = [o['en'] for o in item[k]]
            else:
                new_dict[k] = v
        quest_list.append(new_dict)

# %%
### CHAT GPT UPDATED:

def get_item_data(
    json_file: str | Path = "items.json",
    *,
    locale: str = "en",
    effects_field: str = "effects"
) -> List[Dict[str, Any]]:
    """
    Load item data and normalize:
      - For fields whose value is a dict of localizations, pick `locale`.
      - For the `effects` field (a dict), normalize to a dict of {effect: value}.
        Missing `value` keys are handled gracefully (set to None).
    Returns a list of normalized item dicts.
    """

    path = Path(json_file)

    # Load JSON safely
    try:
        with path.open("r", encoding="utf-8") as f:
            data = json.load(f)
    except FileNotFoundError as e:
        raise FileNotFoundError(f"JSON file not found: {path}") from e
    except json.JSONDecodeError as e:
        raise ValueError(f"Invalid JSON in file: {path}") from e

    if not isinstance(data, list):
        raise TypeError("Top-level JSON must be a list of item objects.")

    # Union of all effect names present across items
    effect_keys = {
        k
        for item in data
        if isinstance(item, dict)
        and isinstance(item.get(effects_field), dict)
        for k in item[effects_field].keys()
    }

    normalized: List[Dict[str, Any]] = []
    for item in data:
        if not isinstance(item, dict):
            continue  # skip malformed entries

        out: Dict[str, Any] = {}
        for k, v in item.items():
            # Pick localized string if available
            if isinstance(v, dict) and locale in v:
                out[k] = v[locale]
            # Normalize effects dict
            elif k == effects_field and isinstance(v, dict):
                # Turn {effect: {"value": X, ...}} into {effect: X}
                # Only include effects that actually exist on this item
                out[k] = {
                    eff: (v.get(eff, {}) or {}).get("value")
                    for eff in effect_keys
                    if eff in v
                }
            else:
                out[k] = v

        normalized.append(out)

    return normalized
# Out:
# [{'id': 'fabric',
#   'name': 'Fabric',
#   'description': 'Used to craft medical supplies and shields. Can be used to slowly restore small amounts of health.',
#   'type': 'Basic Material',
#   'rarity': 'Common',
#   'value': 50,
#   'recyclesInto': {},
#   'imageFilename': 'https://cdn.arctracker.io/items/fabric.png',
#   'weightKg': 0.1,
#   'stackSize': 50,
#   'foundIn': 'Commercial, Medical, Residential',
#   'effects': {'Healing': '0.4/s', 'Duration': '25s', 'Use Time': '1s'},
#   'updatedAt': '10/30/2025'},
#  {'id': 'tick_pod',
#   'name': 'Tick Pod',
#   'description': 'Can be recycled into crafting materials.',
#   'value': 640,
#   'type': 'Recyclable',
#   'rarity': 'Uncommon',
#   'imageFilename': 'https://cdn.arctracker.io/items/tick_pod.png',
#   'recyclesInto': {'arc_alloy': 1, 'metal_parts': 1},
#   'weightKg': 0.5,
#   'stackSize': 3,
#   'foundIn': 'ARC',
#   'updatedAt': '11/03/2025'},
#  {'id': 'explosive_mixture',
#   'name': 'Explosive Mixture',
#   'description': 'A volatile crafting component.',
#   'type': 'Material',
#   'imageFilename': 'https://cdn.arctracker.io/items/explosive_mixture.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'dog_collar',
#   'name': 'Dog Collar',
#   'description': 'After all this time, you can still smell the goodness.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 640,
#   'recyclesInto': {'fabric': 8, 'metal_parts': 1},
#   'salvagesInto': {'fabric': 5},
#   'imageFilename': 'https://cdn.arctracker.io/items/dog_collar.png',
#   'weightKg': 0.8,
#   'stackSize': 3,
#   'foundIn': 'Residential',
#   'updatedAt': '10/30/2025'},
#  {'id': 'torn_blanket',
#   'name': 'Torn Blanket',
#   'description': 'Can be recycled into fabric.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 640,
#   'recyclesInto': {'fabric': 12},
#   'weightKg': 2.0,
#   'stackSize': 3,
#   'foundIn': 'Residential, Medical',
#   'imageFilename': 'https://cdn.arctracker.io/items/torn_blanket.png',
#   'updatedAt': '11/01/2025'},
#  {'id': 'lemon',
#   'name': 'Lemon',
#   'description': 'Can be consumed for a small amount of stamina.',
#   'type': 'Nature',
#   'rarity': 'Uncommon',
#   'value': 640,
#   'recyclesInto': {},
#   'weightKg': 0.2,
#   'stackSize': 10,
#   'foundIn': 'Nature',
#   'effects': {'Stamina': 20, 'Use Time': '1s'},
#   'imageFilename': 'https://cdn.arctracker.io/items/lemon.png',
#   'updatedAt': '11/01/2025'},
#  {'id': 'apricot',
#   'name': 'Apricot',
#   'description': 'A sun ripe apricot. Can be consumed for a small amount of stamina.',
#   'type': 'Nature',
#   'rarity': 'Uncommon',
#   'value': 640,
#   'recyclesInto': {},
#   'weightKg': 0.2,
#   'stackSize': 10,
#   'foundIn': 'Nature',
#   'effects': {'Stamina': 20, 'Use Time': '1s'},
#   'imageFilename': 'https://cdn.arctracker.io/items/apricot.png',
#   'updatedAt': '10/31/2025'},
#  {'id': 'metal_parts',
#   'name': 'Metal Parts',
#   'description': 'Used to craft a wide range of items. Used to craft: Launcher Ammo, Hairpin, Heavy Ammo, Ferro, Kettle',
#   'type': 'Basic Material',
#   'rarity': 'Common',
#   'value': 75,
#   'recyclesInto': {},
#   'weightKg': 0.15,
#   'stackSize': 50,
#   'foundIn': 'Mechanical, Industrial, Electrical, Technological',
#   'imageFilename': 'https://cdn.arctracker.io/items/metal_parts.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'rubber_parts',
#   'name': 'Rubber Parts',
#   'description': 'Scrap rubber pieces for crafting. Used to craft: Ferro, Kettle, Looting Mk. 1, Shield Recharger, Stitcher',
#   'type': 'Basic Material',
#   'rarity': 'Common',
#   'value': 50,
#   'recyclesInto': {},
#   'weightKg': 0.1,
#   'stackSize': 50,
#   'foundIn': 'Mechanical, Industrial, Electrical',
#   'imageFilename': 'https://cdn.arctracker.io/items/rubber_parts.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'plastic_parts',
#   'name': 'Plastic Parts',
#   'description': 'Scrap plastic pieces for crafting. Used to craft: Hairpin, Light Shield, Looting Mk. 1, Light Impact Grenade, Extended Shotgun Mag I',
#   'type': 'Basic Material',
#   'rarity': 'Common',
#   'value': 60,
#   'recyclesInto': {},
#   'weightKg': 0.1,
#   'stackSize': 50,
#   'foundIn': 'Commercial, Residential, Technological',
#   'imageFilename': 'https://cdn.arctracker.io/items/plastic_parts.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'voltage_converter',
#   'name': 'Voltage Converter',
#   'description': 'Used in crafting. Used to craft: Heavy Shield, Showstopper',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 500,
#   'imageFilename': 'https://cdn.arctracker.io/items/voltage_converter.png',
#   'updatedAt': '11/01/2025',
#   'weightKg': 0.3,
#   'stackSize': 5,
#   'foundIn': 'Electrical',
#   'recyclesInto': {'wires': 1, 'rubber_parts': 1}},
#  {'id': 'arc_motion_core',
#   'name': 'ARC Motion Core',
#   'description': 'Obtained from ARC enemies or activities. Used to craft components. Can be recycled into ARC Alloy. Used to craft: Magnetic Accelerator',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'arc_alloy': 2},
#   'weightKg': 0.3,
#   'stackSize': 5,
#   'foundIn': 'ARC',
#   'imageFilename': 'https://cdn.arctracker.io/items/arc_motion_core.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'arc_alloy': 6},
#   'craftBench': 'refiner'},
#  {'id': 'toaster',
#   'name': 'Toaster',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'plastic_parts': 5, 'wires': 3},
#   'salvagesInto': {'wires': 3},
#   'weightKg': 2.0,
#   'stackSize': 3,
#   'foundIn': 'Residential',
#   'imageFilename': 'https://cdn.arctracker.io/items/toaster.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'arc_circuitry',
#   'name': 'ARC Circuitry',
#   'description': 'Obtained from ARC enemies or activities. Used to craft components. Can be recycled into ARC Alloy. Used to craft: Medium Shield, Power Rod',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'arc_alloy': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/arc_circuitry.png',
#   'weightKg': 0.3,
#   'stackSize': 5,
#   'foundIn': 'ARC',
#   'updatedAt': '11/03/2025',
#   'recipe': {'arc_alloy': 6},
#   'craftBench': 'refiner'},
#  {'id': 'motor',
#   'name': 'Motor',
#   'description': 'A small electric motor, useful for various devices.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'oil': 2, 'mechanical_components': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/motor.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'queen_reactor',
#   'tip': 'The Queen Reactor is a legendary item only acquired by defeating The Queen that can be recycled into crafting materials.',
#   'name': 'Queen Reactor',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Legendary',
#   'value': 13000,
#   'recyclesInto': {'power_rod': 1, 'magnetic_accelerator': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/queen_part.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'wires',
#   'name': 'Wires',
#   'tip': 'Wires are an uncommon item used to craft weapon mods that can be recycled into crafting materials.',
#   'description': 'Used to craft a wide range of items. Can be recycled into crafting materials. Used to craft: Blaze Grenade Trap, Smoke Grenade Trap, Lure Grenade Trap, Gas Grenade Trap, Muzzle Brake I',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'value': 200,
#   'recyclesInto': {'rubber_parts': 2},
#   'salvagesInto': {'rubber_parts': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/wires.png',
#   'weightKg': 0.25,
#   'stackSize': 15,
#   'foundIn': 'Electrical, Technological',
#   'updatedAt': '11/03/2025'},
#  {'id': 'hornet_driver',
#   'name': 'Hornet Driver',
#   'tip': 'The Hornet Driver is a rare item is dropped by Hornets that can be recycled into crafting materials.',
#   'description': 'Can be thrown and will briefly stun nearby targets',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 2000,
#   'recyclesInto': {'arc_alloy': 2, 'electrical_components': 2},
#   'salvagesInto': {'electrical_components': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/hornet_driver.png',
#   'effects': {'Radius': '6m',
#    'Raider Stun Duration': '0.5s',
#    'ARC Stun Duration': '10s'},
#   'foundIn': 'ARC',
#   'weightKg': 0.75,
#   'stackSize': 3,
#   'updatedAt': '11/03/2025'},
#  {'id': 'fried_motherboard',
#   'name': 'Fried Motherboard',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'plastic_parts': 5, 'electrical_components': 1},
#   'salvagesInto': {'wires': 5},
#   'imageFilename': 'https://cdn.arctracker.io/items/fried_motherboard.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'rusted_tools',
#   'name': 'Rusted Tools',
#   'description': 'A set of tools, rusted but still usable for crafting.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'metal_parts': 8, 'steel_spring': 1},
#   'salvagesInto': {'metal_parts': 7},
#   'imageFilename': 'https://cdn.arctracker.io/items/rusted_tools.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'wasp_driver',
#   'name': 'Wasp Driver',
#   'tip': 'The Wasp Driver is a rare item is dropped by Wasps that can be recycled into crafting materials.',
#   'description': 'Can be recycled into ARC Alloy. Can be thrown, and will explode if shot.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'arc_alloy': 1, 'electrical_components': 1},
#   'salvagesInto': {'electrical_components': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/wasp_driver.png',
#   'weightKg': 0.6,
#   'stackSize': 3,
#   'foundIn': 'ARC',
#   'effects': {'Radius': '5m', 'Damage': 80},
#   'updatedAt': '11/03/2025'},
#  {'id': 'rusted_gear',
#   'name': 'Rusted Gear',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 3000,
#   'recyclesInto': {'metal_parts': 4, 'mechanical_components': 2},
#   'foundIn': 'Industrial',
#   'updatedAt': '11/04/2025',
#   'weightKg': 3.0,
#   'stackSize': 3,
#   'imageFilename': 'https://cdn.arctracker.io/items/rusted_gear.png'},
#  {'id': 'sentinel_part',
#   'name': 'Sentinel Part',
#   'description': 'A salvaged component from a Sentinel unit.',
#   'type': 'Material',
#   '_note': 'not_in_serverslam',
#   'imageFilename': 'https://cdn.arctracker.io/items/sentinel_part.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'synthesized_fuel',
#   'name': 'Synthesized Fuel',
#   'description': 'A canister of synthetic fuel blend.',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 700,
#   'recyclesInto': {'oil': 1, 'plastic_parts': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/synthesized_fuel.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'fireball_burner',
#   'name': 'Fireball Burner',
#   'description': 'Can be recycled into ARC Alloy. Can be thrown to create small fires.',
#   'type': 'Recyclable',
#   'rarity': 'Uncommon',
#   'value': 640,
#   'recyclesInto': {'arc_alloy': 1, 'crude_explosives': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/fireball_burner.png',
#   'weightKg': 0.5,
#   'stackSize': 3,
#   'foundIn': 'ARC',
#   'effects': {'Radius': '2m', 'Damage': '5/s', 'Duration': '10s'},
#   'updatedAt': '11/03/2025'},
#  {'id': 'laboratory_reagents',
#   'name': 'Laboratory Reagents',
#   'description': 'A set of chemical reagents used in laboratory experiments.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 2000,
#   'recyclesInto': {'chemicals': 2, 'crude_explosives': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/laboratory_reagents.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'syringe',
#   'name': 'Syringe',
#   'description': 'Used to craft medical supplies. Can be recycled into plastic. Used to craft: Vita Shot',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 500,
#   'recyclesInto': {'plastic_parts': 3, 'chemicals': 2},
#   'weightKg': 0.3,
#   'stackSize': 5,
#   'foundIn': 'Medical',
#   'imageFilename': 'https://cdn.arctracker.io/items/syringe.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'antiseptic',
#   'name': 'Antiseptic',
#   'description': 'Used to craft medical supplies. Can be recycled into chemicals. Used to craft: Sterilized Bandage, Vita Spray, Vita Shot',
#   'type': 'Refined Material',
#   'rarity': 'Rare',
#   'recyclesInto': {'chemicals': 10},
#   'imageFilename': 'https://cdn.arctracker.io/items/antiseptic.png',
#   'foundIn': 'Medical',
#   'weightKg': 1.0,
#   'stackSize': 5,
#   'value': 1000,
#   'updatedAt': '11/03/2025',
#   'recipe': {'chemicals': 10, 'great_mullein': 2},
#   'craftBench': 'refiner'},
#  {'id': 'snitch_scanner',
#   'name': 'Snitch Scanner',
#   'description': 'Can be recycled into ARC Alloy. Can be thrown to call in ARC.',
#   'type': 'Recyclable',
#   'rarity': 'Uncommon',
#   'value': 2000,
#   'recyclesInto': {'arc_alloy': 4},
#   'imageFilename': 'https://cdn.arctracker.io/items/snitch_scanner.png',
#   'updatedAt': '10/31/2025',
#   'weightKg': 0.75,
#   'stackSize': 3,
#   'foundIn': 'ARC'},
#  {'id': 'rusted_shut_medical_kit',
#   'name': 'Rusted Shut Medical Kit',
#   'description': 'A medical kit rusted shut, its contents unknown.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'syringe': 2, 'antiseptic': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/rusted_shut_medical_kit.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'spring',
#   'name': 'Spring',
#   'description': 'A tightly wound coil of metal, useful for crafting mechanisms.',
#   'type': 'Material',
#   '_note': 'not_in_serverslam',
#   'imageFilename': 'https://cdn.arctracker.io/items/spring.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'heavy_gun_parts',
#   'name': 'Heavy Gun Parts',
#   'description': 'Used to craft weapons. Used to craft: Vulcano, Hullcracker, Bettina, Complex Gun Parts',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 700,
#   'recyclesInto': {'simple_gun_parts': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/heavy_gun_parts.png',
#   'weightKg': 0.5,
#   'stackSize': 5,
#   'foundIn': 'Security, Raider',
#   'updatedAt': '11/03/2025',
#   'recipe': {'simple_gun_parts': 4},
#   'craftBench': 'refiner'},
#  {'id': 'arc_alloy',
#   'name': 'ARC Alloy',
#   'description': 'Obtained from ARC enemies or activities, or by recycling certain ARC parts. Used to craft components. Used to craft: Light Shield, ARC Motion Core, ARC Circuitry',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'value': 200,
#   'recyclesInto': {'metal_parts': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/arc_alloy.png',
#   'weightKg': 0.25,
#   'stackSize': 15,
#   'foundIn': 'ARC',
#   'updatedAt': '11/03/2025'},
#  {'id': 'ferro_i',
#   'name': 'Ferro I',
#   'description': 'Packs a punch, but must be reloaded between every shot.',
#   'type': 'Battle Rifle',
#   'rarity': 'Common',
#   'value': 475,
#   'recyleInto': {'metal_parts': 2, 'rubber_parts': 1},
#   'craftMaterials': {'metal_parts': 5, 'rubber_parts': 2},
#   'repairMaterials': {'durability_increase': 50, 'materials': None},
#   'salvagesInto': {'metal_parts': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/ferro.png',
#   'updatedAt': '11/03/2025',
#   'weightKg': 8.0,
#   'effects': {'Durability': '100/100',
#    'ARC Armor Penetration': 'Strong',
#    'Ammo Type': 'Heavy Ammo',
#    'Firing Mode': 'Break-Action',
#    'Magazine Size': 1},
#   'recipe': {'metal_parts': 5, 'rubber_parts': 2},
#   'craftBench': ['workbench', 'weapon_bench']},
#  {'id': 'light_ammo',
#   'name': 'Light Ammo',
#   'description': 'Light bullets used mainly with SMGs and light handguns. Compatible with: Burletta, Stitcher, Kettle, Hairpin, Bobcat',
#   'type': 'Ammunition',
#   'imageFilename': 'https://cdn.arctracker.io/items/light_ammo.png',
#   'compatibleWith': ['Kettle', 'Burletta', 'Hairpin', 'Bobcat', 'Stitcher'],
#   'value': 0.76,
#   'weightKg': 0.00323,
#   'stackSize': 100,
#   'updatedAt': '11/03/2025',
#   'recipe': {'metal_parts': 3, 'chemicals': 2},
#   'craftBench': 'workbench'},
#  {'id': 'heavy_ammo',
#   'name': 'Heavy Ammo',
#   'description': 'Compatible with: Ferro, Anvil, Bettina',
#   'type': 'Ammunition',
#   'compatibleWith': ['Anvil', 'Ferro', 'Bettina'],
#   'updatedAt': '11/03/2025',
#   'value': 12,
#   'weightKg': 0.05,
#   'stackSize': 40,
#   'imageFilename': 'https://cdn.arctracker.io/items/heavy_ammo.png',
#   'rarity': 'Common',
#   'recipe': {'metal_parts': 3, 'chemicals': 2},
#   'craftBench': 'workbench'},
#  {'id': 'medium_ammo',
#   'name': 'Medium Ammo',
#   'description': 'Compatible with: Rattler, Tempest, Arpeggio, Renegade, Torrente',
#   'type': 'Ammunition',
#   'compatibleWith': ['Arpeggio', 'Rattler', 'Tempest', 'Renegade', 'Torrente'],
#   'imageFilename': 'https://cdn.arctracker.io/items/medium_ammo.png',
#   'crafting': {'metal_parts': 4, 'chemicals': 2},
#   'value': 6,
#   'weightKg': 0.025,
#   'stackSize': 80,
#   'rarity': 'Common',
#   'updatedAt': '11/03/2025',
#   'recipe': {'metal_parts': 3, 'chemicals': 2},
#   'craftBench': 'workbench'},
#  {'id': 'sterilized_bandage',
#   'name': 'Sterilized Bandage',
#   'description': 'A medical item that gradually restores a large amount of health over time.',
#   'type': 'Quick Use',
#   'imageFilename': 'https://cdn.arctracker.io/items/sterilized_bandage.png',
#   'value': 2000,
#   'rarity': 'Rare',
#   'weightKg': 0.2,
#   'effects': {'Healing': '5/s', 'Duration': '10s', 'Use Time': '1.5s'},
#   'updatedAt': '11/03/2025',
#   'stackSize': 3,
#   'recipe': {'antiseptic': 1, 'durable_cloth': 2},
#   'craftBench': 'med_station'},
#  {'id': 'lure_grenade',
#   'name': 'Lure Grenade',
#   'description': 'A noise device that sticks to surfaces, distracting nearby ARC machines and drawing their fire.',
#   'type': 'Quick Use',
#   'rarity': 'Uncommon',
#   'value': 1000,
#   'imageFilename': 'https://cdn.arctracker.io/items/lure_grenade.png',
#   'updatedAt': '10/30/2025',
#   'recipe': {'speaker_component': 1, 'electrical_components': 1},
#   'craftBench': 'utility_bench'},
#  {'id': 'jump_mine',
#   'name': 'Jump Mine',
#   'description': 'A proximity triggered mine that pops up and explodes, dealing damage to anything within its radius.',
#   'type': 'Quick Use',
#   'rarity': 'Uncommon',
#   'value': 1000,
#   'updatedAt': '10/30/2025'},
#  {'id': 'ferro_iv',
#   'name': 'Ferro IV',
#   'description': 'Packs a punch, but must be reloaded between every shot.',
#   'type': 'Battle Rifle',
#   'rarity': 'Common',
#   'value': 2900,
#   'durability': 130,
#   'recyclesInto': {'mechanical_components': 1, 'simple_gun_parts': 2},
#   'craftMaterials': {'metal_parts': 5, 'rubber_parts': 2},
#   'repairMaterials': {'durability_increase': 50, 'materials': None},
#   'salvagesInto': {'metal_parts': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/ferro.png',
#   'updatedAt': '11/03/2025',
#   'weightKg': 8.0,
#   'effects': {'Durability': '130/130',
#    'ARC Armor Penetration': 'Strong',
#    'Ammo Type': 'Heavy Ammo',
#    'Firing Mode': 'Break-Action',
#    'Upgrade Modifiers': '39% Reduced Reload Time',
#    'Magazine Size': 1}},
#  {'id': 'blaze_grenade',
#   'name': 'Blaze Grenade',
#   'description': 'A grenade that detonates on impact, covering an area in fire that deals damage over time.',
#   'type': 'Quick Use',
#   'rarity': 'Rare',
#   'value': 1600,
#   'imageFilename': 'https://cdn.arctracker.io/items/blaze_grenade.png',
#   'recyclesInto': {'oil': 2, 'metal_parts': 4},
#   'weightKg': 0.2,
#   'stackSize': 5,
#   'effects': {'Radius': '10m', 'Damage': '5/s', 'Duration': '10s'},
#   'updatedAt': '10/30/2025'},
#  {'id': 'apreggio_iv',
#   'name': 'Apreggio IV',
#   'baseItemId': 'apreggio_rifle',
#   'tier': 4,
#   'description': 'A 3-round burst assault rifle with decent damage output and accuracy.',
#   'type': 'Assault Rifle',
#   'rarity': 'Uncommon',
#   'imageFilename': 'https://cdn.arctracker.io/items/arpeggio.png',
#   'tags': ['Assault Rifle', 'Burst'],
#   'flavorText': 'Somewhat effective against ARC armor plating',
#   'ammoType': 'Medium Ammo',
#   'magazineSize': 24,
#   'magazineCurrent': 24,
#   'modsEquippedMax': 4,
#   'statBars': {'damage': 20,
#    'fireRate': 70,
#    'range': 40,
#    'stability': 85,
#    'agility': 30,
#    'stealth': 25},
#   'bonuses': ['60% Increased Fire Rate',
#    '50% Reduced Reload Time',
#    '70% Reduced Durability Burn Rate'],
#   'weightKg': 6,
#   'value': 7000,
#   'updatedAt': '10/30/2025'},
#  {'id': 'rubber_duck',
#   'name': 'Rubber Duck',
#   'description': 'Always there to lend an ear when you need it. Can be thrown to create noise.',
#   'type': 'Trinket',
#   'rarity': 'Common',
#   'value': 1000,
#   'recyclesInto': {},
#   'weightKg': 0.3,
#   'stackSize': 15,
#   'imageFilename': 'https://cdn.arctracker.io/items/rubber_duck.png',
#   'updatedAt': '11/04/2025'},
#  {'id': 'arc_powercell',
#   'name': 'ARC Powercell',
#   'description': 'Valuable resource that drops from all ARC enemies. Used to craft: Shield Recharger Can be used to repair shields.',
#   'type': 'Topside Material',
#   'rarity': 'Common',
#   'value': 640,
#   'recyclesInto': {},
#   'imageFilename': 'https://cdn.arctracker.io/items/arc_powercell.png',
#   'weightKg': 0.5,
#   'stackSize': 5,
#   'foundIn': 'ARC',
#   'effects': {'Recharge': '2/s', 'Duration': '10s', 'Use Time': '3s'},
#   'updatedAt': '11/03/2025'},
#  {'id': 'water_filter',
#   'name': 'Water Filter',
#   'description': 'A portable filtration device for purifying water.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'weightKg': 2,
#   'stackSize': 3,
#   'foundIn': 'Industrial',
#   'recyclesInto': {'rubber_parts': 2, 'canister': 3},
#   'salvagesInto': {'canister': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/water_filter.png',
#   'updatedAt': '11/1/2025'},
#  {'id': 'water_pump',
#   'name': 'Water Pump',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'stackSize': 3,
#   'weightKg': 2.0,
#   'value': 1000,
#   'recyclesInto': {'metal_parts': 4, 'oil': 2},
#   'salvagesInto': {'oil': 2},
#   'foundIn': 'Mechanical, Industrial',
#   'imageFilename': 'https://cdn.arctracker.io/items/water_pump.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'advanced_electrical_components',
#   'name': 'Advanced Electrical Components',
#   'description': 'Used to craft a wide range of items. Can be recycled into crafting materials. Used to craft: Tactical Mk. 3 (Defensive), Combat Mk. 3 (Flanking), Combat Mk. 3 (Aggressive), Looting Mk. 3 (Cautious), Tactical Mk. 3 (Healing)',
#   'type': 'Refined Material',
#   'rarity': 'Rare',
#   'value': 1750,
#   'recyclesInto': {'electrical_components': 1, 'wires': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/advanced_electrical_components.png',
#   'salvagesInto': {'electrical_components': 1},
#   'foundIn': 'Electrical',
#   'weightKg': 1.0,
#   'stackSize': 5,
#   'updatedAt': '11/03/2025',
#   'recipe': {'wires': 3, 'electrical_components': 2},
#   'craftBench': 'refiner'},
#  {'id': 'deflated_football',
#   'name': 'Deflated Football',
#   'description': 'Just by looking at this, you too start to feel slightly deflated.',
#   'type': 'Recyclable',
#   'recyclesInto': {'rubber_parts': 15},
#   'salvagesInto': {'rubber_parts': 9},
#   'imageFilename': 'https://cdn.arctracker.io/items/deflated_football.png',
#   'rarity': 'Uncommon',
#   'weightKg': 0.8,
#   'stackSize': 3,
#   'foundIn': 'Residential',
#   'updatedAt': '10/30/2025'},
#  {'id': 'duct_tape',
#   'name': 'Duct Tape',
#   'imageFilename': 'https://cdn.arctracker.io/items/duct_tape.png',
#   'value': 300,
#   'recyclesInto': {'fabric': 3},
#   'description': 'Used to craft a wide range of items. Can be recycled into crafting materials. Used to craft: Stable Stock I, Vertical Grip I, Angled Grip I, Vertical Grip II, Angled Grip II',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'weightKg': 0.25,
#   'stackSize': 15,
#   'foundIn': 'Residential, Commercial',
#   'updatedAt': '11/03/2025'},
#  {'id': 'empty_wine_bottle',
#   'name': 'Empty Wine Bottle',
#   'description': 'Yes, it really is empty.',
#   'type': 'Trinket',
#   'value': 1000,
#   'weightKg': 0.2,
#   'stackSize': 5,
#   'foundIn': 'Residential, Commercial',
#   'imageFilename': 'https://cdn.arctracker.io/items/empty_wine_bottle.png',
#   'rarity': 'Common',
#   'updatedAt': '11/04/2025'},
#  {'id': 'light_impact_grenade',
#   'name': 'Light Impact Grenade',
#   'description': 'A grenade that detonates on impact, dealing explosive damage in a small radius.',
#   'type': 'Quick Use',
#   'rarity': 'Common',
#   'value': 270,
#   'imageFilename': 'https://cdn.arctracker.io/items/light_impact_grenade.png',
#   'recyclesInto': {'chemicals': 1, 'plastic_parts': 1},
#   'salvagesInto': {'chemicals': 1},
#   'weightKg': 0.1,
#   'stackSize': 5,
#   'effects': {'Radius': '2.5m', 'Damage': 30},
#   'updatedAt': '11/03/2025',
#   'recipe': {'chemicals': 3, 'plastic_parts': 2},
#   'craftBench': ['workbench', 'explosives_bench']},
#  {'id': 'shrapnel_grenade',
#   'name': 'Shrapnel Grenade',
#   'description': 'A makeshift fuze grenade that bursts into razor-sharp fragments upon detonation. Weak against ARC armor plating',
#   'type': 'Quick Use',
#   'rarity': 'Uncommon',
#   'value': 800,
#   'recyclesInto': {'crude_explosives': 1, 'metal_parts': 1},
#   'effects': {'Radius': '6m', 'Damage': 60},
#   'weightKg': 0.15,
#   'stackSize': 5,
#   'updatedAt': '11/03/2025',
#   'recipe': {'crude_explosives': 1, 'steel_spring': 2},
#   'craftBench': 'explosives_bench',
#   'imageFilename': 'https://cdn.arctracker.io/items/shrapnel_grenade.png'},
#  {'id': 'oil',
#   'name': 'Oil',
#   'description': 'Used to craft weapons and explosives. Can be recycled into chemicals. Used to craft: Renegade, Explosive Compound, Blaze Grenade',
#   'imageFilename': 'https://cdn.arctracker.io/items/oil.png',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'value': 300,
#   'recyclesInto': {'chemicals': 3},
#   'updatedAt': '11/03/2025',
#   'weightKg': 0.25,
#   'stackSize': 15,
#   'foundIn': 'Mechanical'},
#  {'id': 'snap_hook',
#   'name': 'Snap Hook',
#   'description': 'A gadget that allows the user to scale structures and cover large distances.',
#   'type': 'Quick Use',
#   'rarity': 'Legendary',
#   'value': 14000,
#   'imageFilename': 'https://cdn.arctracker.io/items/snap_hook.png',
#   'weightKg': 5.0,
#   'effects': {'Durability': '100/100', 'Range': '20m'},
#   'recipe': {'power_rod': 1, 'exodus_modules': 1},
#   'craftBench': 'utility_bench',
#   'updatedAt': '11/05/2025'},
#  {'id': 'esr_analyzer',
#   'name': 'ESR Analyzer',
#   'description': 'A specialized medical device for analyzing erythrocyte sedimentation rates.',
#   'type': 'Misc',
#   'updatedAt': '10/30/2025'},
#  {'id': 'wolfpack',
#   'name': 'Wolfpack',
#   'description': 'A grenade that scatters into multiple homing missiles, each one targeting ARC and dealing explosive damage on impact.',
#   'type': 'Quick Use',
#   'rarity': 'Epic',
#   'weightKg': 1.0,
#   'effects': {'Homing Range': '100m', 'Damage': '166 x12'},
#   'imageFilename': 'https://cdn.arctracker.io/items/wolfpack.png',
#   'updatedAt': '10/30/2025',
#   'recyclesInto': {'crude_explosives': 2, 'synthesized_fuel': 2}},
#  {'id': 'camera_lens',
#   'name': 'Camera Lens',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Uncommon',
#   'value': 640,
#   'recyclesInto': {'plastic_parts': 8},
#   'salvagesInto': {'plastic_parts': 4},
#   'weightKg': 0.8,
#   'stackSize': 5,
#   'foundIn': 'Security',
#   'imageFilename': 'https://cdn.arctracker.io/items/camera_lens.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'film_reel',
#   'name': 'Film Reel',
#   'description': 'May be worth a few coins.',
#   'type': 'Trinket',
#   'value': 2000,
#   'recyclesInto': {},
#   'rarity': 'Rare',
#   'weightKg': 0.2,
#   'stackSize': 3,
#   'foundIn': 'Old World, Residential',
#   'updatedAt': '11/03/2025',
#   'imageFilename': 'https://cdn.arctracker.io/items/film_reel.png'},
#  {'id': 'electrical_components',
#   'name': 'Electrical Components',
#   'description': 'Used to craft a wide range of items. Can be recycled into crafting materials. Used to craft: Tactical Mk. 2, Combat Mk. 2, Looting Mk. 2, Surge Shield Recharger, Lure Grenade',
#   'type': 'Refined Material',
#   'value': 640,
#   'recyclesInto': {'plastic_parts': 3, 'rubber_parts': 3},
#   'salvagesInto': {'plastic_parts': 3},
#   'imageFilename': 'https://cdn.arctracker.io/items/electrical_components.png',
#   'rarity': 'Uncommon',
#   'weightKg': 0.5,
#   'stackSize': 10,
#   'foundIn': 'Electrical',
#   'updatedAt': '11/03/2025',
#   'recipe': {'plastic_parts': 8, 'rubber_parts': 4},
#   'craftBench': 'refiner'},
#  {'id': 'canister',
#   'name': 'Canister',
#   'description': 'Used to craft a wide range of items. Can be recycled into plastic. Used to craft: Bettina, Vita Spray, Heavy Fuze Grenade, Smoke Grenade',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'value': 300,
#   'recyclesInto': {'plastic_parts': 3},
#   'imageFilename': 'https://cdn.arctracker.io/items/canister.png',
#   'weightKg': 0.25,
#   'stackSize': 15,
#   'foundIn': 'Commercial',
#   'updatedAt': '11/03/2025'},
#  {'id': 'advanced_mechanical_components',
#   'name': 'Advanced Mechanical Components',
#   'description': 'Used to craft advanced weapons. Can be recycled into crafting materials. Used to craft: Torrente, Venator, Osprey, Renegade, Bettina',
#   'type': 'Refined Material',
#   'rarity': 'Rare',
#   'value': 1750,
#   'recyclesInto': {'mechanical_components': 1, 'wires': 1},
#   'weightKg': 1.0,
#   'imageFilename': 'https://cdn.arctracker.io/items/advanced_mechanical_components.png',
#   'foundIn': 'Mechanical',
#   'updatedAt': '11/03/2025',
#   'stackSize': 5,
#   'recipe': {'steel_spring': 2, 'mechanical_components': 2},
#   'craftBench': 'refiner'},
#  {'id': 'simple_gun_parts',
#   'name': 'Simple Gun Parts',
#   'description': 'Used to craft weapons. Used to craft: Il Toro, Burletta, Anvil, Arpeggio, Heavy Gun Parts',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'value': 330,
#   'recyclesInto': {'metal_parts': 2},
#   'updatedAt': '10/31/2025',
#   'weightKg': 0.3,
#   'stackSize': 10,
#   'foundIn': 'Raider, Security',
#   'imageFilename': 'https://cdn.arctracker.io/items/simple_gun_parts.png'},
#  {'id': 'mechanical_components',
#   'name': 'Mechanical Components',
#   'description': 'Used to craft a wide range of items. Can be recycled into crafting materials. Used to craft: Il Toro, Burletta, Anvil, Muzzle Brake II, Extended Medium Mag II',
#   'type': 'Refined Material',
#   'rarity': 'Uncommon',
#   'value': 640,
#   'recyclesInto': {'metal_parts': 8, 'steel_spring': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/mechanical_components.png',
#   'updatedAt': '11/03/2025',
#   'weightKg': 0.5,
#   'stackSize': 10,
#   'foundIn': 'Mechanical',
#   'recipe': {'metal_parts': 7, 'rubber_parts': 3},
#   'craftBench': 'refiner'},
#  {'id': 'arpeggio_i',
#   'name': 'Arpeggio I',
#   'description': 'Has decent damage output and accuracy.',
#   'type': 'Weapon',
#   'rarity': 'Uncommon',
#   'damage': 11,
#   'fireRate': 18.3,
#   'range': 53.7,
#   'stability': 82.4,
#   'agility': 60,
#   'stealth': 14,
#   'crafting': {'mechanical_components': 1, 'magnet': 3},
#   'imageFilename': 'https://cdn.arctracker.io/items/arpeggio.png',
#   'updatedAt': '11/03/2025',
#   'value': 5500,
#   'weightKg': 6.0,
#   'effects': {'Durability': '100/100',
#    'ARC Armor Penetration': 'Moderate',
#    'Ammo Type': 'Medium Ammo',
#    'Firing Mode': '3-Round Burst',
#    'Magazine Size': 24},
#   'recipe': {'mechanical_components': 6, 'simple_gun_parts': 6},
#   'craftBench': 'weapon_bench'},
#  {'id': 'venator_i',
#   'name': 'Venator I',
#   'description': 'Semi-automatic pistol. Fires two shots at a time.',
#   'type': 'Pistol',
#   'rarity': 'Rare',
#   '_note': 'not_in_serverslam',
#   'damage': 18,
#   'fireRate': 21.7,
#   'range': 48.4,
#   'stability': 71.2,
#   'agility': 77.6,
#   'stealth': 12,
#   'crafting': {'advanced_mechanical_components': 2, 'magnet': 4},
#   'recipe': {'advanced_mechanical_components': 2,
#    'medium_gun_parts': 3,
#    'magnet': 5},
#   'craftBench': 'weapon_bench',
#   'stationLevelRequired': 2,
#   'imageFilename': 'https://cdn.arctracker.io/items/venator.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'vulcano_i',
#   'name': 'Vulcano I',
#   'description': 'Semi-automatic shotgun with good bullet spread but sharp falloff.',
#   'type': 'Shotgun',
#   'rarity': 'Epic',
#   '_note': 'not_in_serverslam',
#   'damage': 58.5,
#   'fireRate': 8.3,
#   'range': 22.1,
#   'stability': 70.3,
#   'agility': 70.7,
#   'stealth': 15,
#   'increasedFireRate': 10,
#   'reducedReloadTime': 13,
#   'reducedDurabilityBurnRate': 23,
#   'crafting': {'advanced_mechanical_components': 3, 'canister': 4},
#   'stationLevelRequired': 3,
#   'imageFilename': 'https://cdn.arctracker.io/items/vulcano.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'vulcano_ii',
#   'name': 'Vulcano II',
#   'description': 'Has good bullet spread but sharp falloff.',
#   'type': 'Weapon',
#   'rarity': 'Epic',
#   '_note': 'not_in_serverslam',
#   'damage': 58.5,
#   'fireRate': 14.3,
#   'range': 22.1,
#   'stability': 70.3,
#   'agility': 70.7,
#   'stealth': 15,
#   'increasedFireRate': 20,
#   'reducedReloadTime': 26,
#   'reducedDurabilityBurnRate': 46,
#   'crafting': {'mechanical_components': 1, 'simple_gun_parts': 3},
#   'imageFilename': 'https://cdn.arctracker.io/items/vulcano.png',
#   'updatedAt': '11/01/2025',
#   'value': 16800,
#   'weightKg': 9.25,
#   'stackSize': 1,
#   'effects': {'Durability': '100/110',
#    'ARC Armor Penetration': 'Weak',
#    'Ammo Type': 'Shotgun Ammo',
#    'Firing Mode': 'Semi-Automatic',
#    'Magazine Size': 10}},
#  {'id': 'venator_ii',
#   'name': 'Venator II',
#   'description': 'Semi-automatic pistol. Fires two shots at a time.',
#   'type': 'Pistol',
#   'rarity': 'Rare',
#   '_note': 'not_in_serverslam',
#   'damage': 18,
#   'fireRate': 26.7,
#   'range': 48.4,
#   'stability': 71.2,
#   'agility': 77.6,
#   'stealth': 12,
#   'increasedFireRate': 22,
#   'reducedReloadTime': 16,
#   'reducedDurabilityBurnRate': 23,
#   'crafting': {'mechanical_components': 1, 'simple_gun_parts': 3},
#   'imageFilename': 'https://cdn.arctracker.io/items/venator.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'arpeggio_iii',
#   'name': 'Arpeggio III',
#   'description': 'A 3-round burst assault rifle with decent damage output and accuracy.',
#   'type': 'Assault Rifle',
#   'rarity': 'Uncommon',
#   '_note': 'not_in_serverslam',
#   'damage': 11,
#   'fireRate': 18.3,
#   'range': 53.7,
#   'stability': 82.4,
#   'agility': 60,
#   'stealth': 14,
#   'increasedFireRate': 40,
#   'reducedReloadTime': 25,
#   'reducedDurabilityBurnRate': 46,
#   'imageFilename': 'https://cdn.arctracker.io/items/arpeggio.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'arpeggio_iv',
#   'name': 'Arpeggio IV',
#   'description': 'A 3-round burst assault rifle with decent damage output and accuracy.',
#   'type': 'Assault Rifle',
#   'rarity': 'Uncommon',
#   '_note': 'not_in_serverslam',
#   'damage': 11,
#   'fireRate': 23.3,
#   'range': 53.7,
#   'stability': 82.4,
#   'agility': 60,
#   'stealth': 14,
#   'increasedFireRate': 60,
#   'reducedReloadTime': 50,
#   'reducedDurabilityBurnRate': 70,
#   'crafting': {'mechanical_components': 1, 'medium_gun_parts': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/arpeggio.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'anvil_iii',
#   'name': 'Anvil III',
#   'description': 'Single-action hand cannon with high damage output and headshot damage, but slow handling.',
#   'type': 'Hand Cannon',
#   'rarity': 'Uncommon',
#   '_note': 'not_in_serverslam',
#   'damage': 40,
#   'fireRate': 14.7,
#   'range': 51.3,
#   'stability': 66.5,
#   'agility': 68,
#   'stealth': 10,
#   'reducedDispersionRecoveryTime': 30,
#   'increasedFireRate': 30,
#   'reducedDurabilityBurnRate': 46,
#   'imageFilename': 'https://cdn.arctracker.io/items/anvil.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'anvil_iv',
#   'name': 'Anvil IV',
#   'description': 'Single-action hand cannon with high damage output and headshot damage, but slow handling.',
#   'type': 'Hand Cannon',
#   'rarity': 'Uncommon',
#   '_note': 'not_in_serverslam',
#   'damage': 40,
#   'fireRate': 20.7,
#   'range': 51.3,
#   'stability': 66.5,
#   'agility': 74,
#   'stealth': 10,
#   'reducedDispersionRecoveryTime': 45,
#   'increasedFireRate': 45,
#   'reducedDurabilityBurnRate': 62,
#   'crafting': {'mechanical_components': 1, 'heavy_gun_parts': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/anvil.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'medium_gun_parts',
#   'name': 'Medium Gun Parts',
#   'description': 'Assorted spare parts used for rifles. Used to craft: Torrente, Venator, Osprey, Renegade, Tempest',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 700,
#   'recyclesInto': {'simple_gun_parts': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/medium_gun_parts.png',
#   'foundIn': 'Raider, Security',
#   'stackSize': 5,
#   'weightKg': 0.4,
#   'updatedAt': '11/03/2025',
#   'recipe': {'simple_gun_parts': 4},
#   'craftBench': 'refiner'},
#  {'id': 'chemicals',
#   'name': 'Chemicals',
#   'description': 'Used to craft medical supplies, explosives, and utility items. Used to craft: Heavy Ammo, Medium Ammo, Shotgun Ammo, Light Ammo, Light Impact Grenade',
#   'type': 'Basic Material',
#   'rarity': 'Common',
#   'value': 50,
#   'weightKg': 0.15,
#   'stackSize': 50,
#   'foundIn': 'Medical, Residential, Mechanical',
#   'imageFilename': 'https://cdn.arctracker.io/items/power_rod.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'power_rod',
#   'name': 'Power Rod',
#   'description': 'Used in crafting. Used to craft: Heavy Shield, Snap Hook',
#   'type': 'Refined Material',
#   'rarity': 'Epic',
#   'weightKg': 2.0,
#   'value': 5500,
#   'recyclesInto': {'advanced_electrical_components': 1, 'arc_circuitry': 1},
#   'imageFilename': 'https://cdn.arctracker.io/items/power_rod.png',
#   'updatedAt': '11/03/2025',
#   'foundIn': 'Exodus',
#   'recipe': {'advanced_electrical_components': 2, 'arc_circuitry': 2},
#   'craftBench': 'refiner'},
#  {'id': 'industrial_battery',
#   'name': 'Industrial Battery',
#   'description': 'A large, high-capacity battery for industrial equipment.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'chemicals': 7, 'battery': 2},
#   'salvagesInto': {'battery': 2},
#   'weightKg': 2.0,
#   'stackSize': 3,
#   'foundIn': 'Industrial',
#   'imageFilename': 'https://cdn.arctracker.io/items/industrial_battery.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'power_cable',
#   'name': 'Power Cable',
#   'description': 'A heavy-duty cable used for transmitting electrical power.',
#   'type': 'Recyclable',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'wires': 4},
#   'stackSize': 3,
#   'weightKg': 2.0,
#   'foundIn': 'Electrical, Residential, Commercial',
#   'imageFilename': 'https://cdn.arctracker.io/items/power_cable.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'processor',
#   'name': 'Processor',
#   'description': 'Used in crafting. Used to craft: Tactical Mk. 3 (Defensive), Combat Mk. 3 (Flanking), Combat Mk. 3 (Aggressive), Looting Mk. 3 (Cautious), Tactical Mk. 3 (Healing)',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 500,
#   'recyclesInto': {'wires': 1, 'plastic_parts': 1},
#   'weightKg': 0.2,
#   'stackSize': 5,
#   'foundIn': 'Technological',
#   'imageFilename': 'https://cdn.arctracker.io/items/processor.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'battery',
#   'name': 'Battery',
#   'description': 'Used to craft a wide range of items. Can be recycled into scrap metal. Used to craft: Energy Clip, Medium Shield, Jolt Mine',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'imageFilename': 'https://cdn.arctracker.io/items/battery.png',
#   'value': 250,
#   'recyclesInto': {'metal_parts': 2},
#   'foundIn': 'Technological, Electrical',
#   'stackSize': 15,
#   'weightKg': 0.25,
#   'updatedAt': '11/03/2025'},
#  {'id': 'sensors',
#   'name': 'Sensors',
#   'description': 'Used in crafting. Used to craft: Wolfpack, Explosive Mine, Raider Hatch Key, Tagging Grenade',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 500,
#   'recyclesInto': {'wires': 1, 'metal_parts': 1},
#   'salvagesInto': {'wires': 1},
#   'weightKg': 0.3,
#   'stackSize': 5,
#   'foundIn': 'Security, Technological',
#   'imageFilename': 'https://cdn.arctracker.io/items/sensors.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'steel_spring',
#   'name': 'Steel Spring',
#   'description': 'Used to craft a wide range of items. Can be recycled into crafting materials. Used to craft: Extended Shotgun Mag I, Extended Medium Mag I, Extended Light Mag I, Torrente, Extended Medium Mag II',
#   'imageFilename': 'https://cdn.arctracker.io/items/steel_spring.png',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'value': 300,
#   'recyclesInto': {'metal_parts': 3},
#   'salvagesInto': {'metal_parts': 2},
#   'weightKg': 0.25,
#   'stackSize': 15,
#   'foundIn': 'Industrial',
#   'updatedAt': '11/03/2025'},
#  {'id': 'speaker_component',
#   'name': 'Speaker Component',
#   'description': 'Used in crafting. Used to craft: Lure Grenade, Photoelectric Cloak',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'value': 500,
#   'recyclesInto': {'plastic_parts': 2, 'rubber_parts': 3},
#   'weightKg': 0.3,
#   'stackSize': 5,
#   'foundIn': 'Commercial',
#   'imageFilename': 'https://cdn.arctracker.io/items/speaker_component.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'magnet',
#   'name': 'Magnet',
#   'description': 'Used to craft a wide range of items. Can be recycled into crafting materials.',
#   'type': 'Topside Material',
#   'rarity': 'Uncommon',
#   'value': 300,
#   'recyclesInto': {'metal_parts': 3},
#   'updatedAt': '10/31/2025',
#   'weightKg': 0.25,
#   'stackSize': 15,
#   'foundIn': 'Exodus',
#   'imageFilename': 'https://cdn.arctracker.io/items/magnet.png'},
#  {'id': 'advanced_arc_powercell',
#   'name': 'Advanced ARC Powercell',
#   'description': 'Very valuable resource that drops from certain ARC enemies.',
#   'type': 'Topside Material',
#   'rarity': 'Rare',
#   'recyclesInto': {'arc_powercell': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/advanced_arc_powercell.png',
#   'value': 640,
#   'weightKg': 0.5,
#   'stackSize': 5,
#   'foundIn': 'ARC',
#   'updatedAt': '11/05/2025'},
#  {'id': 'arc_coolant',
#   'name': 'ARC Coolant',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 1000,
#   'recyclesInto': {'chemicals': 16},
#   'description': 'Obtained from ARC enemies or activities. Can be recycled into chemicals.',
#   'weightKg': 1.0,
#   'stackSize': 3,
#   'foundIn': 'ARC',
#   'imageFilename': 'https://cdn.arctracker.io/items/arc_coolant.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'arc_performance_steel',
#   'name': 'ARC Performance Steel',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 1000,
#   'recyclesInto': {'metal_parts': 12},
#   'description': 'Can be recycled into crafting materials.',
#   'weightKg': 1.0,
#   'foundIn': 'ARC',
#   'imageFilename': 'https://cdn.arctracker.io/items/arc_performance_steel.png',
#   'updatedAt': '11/01/2025',
#   'stackSize': 3},
#  {'id': 'arc_synthetic_resin',
#   'name': 'ARC Synthetic Resin',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 1000,
#   'recyclesInto': {'plastic_parts': 14},
#   'description': 'Obtained from ARC enemies or activities. Can be recycled into plastic.',
#   'foundIn': 'ARC',
#   'imageFilename': 'https://cdn.arctracker.io/items/arc_synthetic_resin.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'arc_thermo_lining',
#   'name': 'ARC Thermo Lining',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 1000,
#   'recyclesInto': {'fabric': 16},
#   'description': 'Obtained from ARC enemies or activities. Can be recycled into fabric.',
#   'weightKg': 1.0,
#   'stackSize': 3,
#   'foundIn': 'ARC',
#   'imageFilename': 'https://cdn.arctracker.io/items/arc_thermo_lining.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'bastion_cell',
#   'name': 'Bastion Cell',
#   'rarity': 'Epic',
#   'type': 'Recyclable',
#   'value': 5000,
#   'recyclesInto': {'arc_alloy': 2, 'advanced_mechanical_components': 2},
#   'description': 'Can be recycled into crafting materials.',
#   'weightKg': 1.0,
#   'stackSize': 3,
#   'foundIn': 'ARC',
#   'imageFilename': 'https://cdn.arctracker.io/items/bastion_cell.png',
#   'updatedAt': '11/01/2025'},
#  {'id': 'bicycle_pump',
#   'name': 'Bicycle Pump',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 2000,
#   'recyclesInto': {'canister': 4, 'metal_parts': 10},
#   'salvagesInto': {'canister': 3},
#   'description': 'Can be recycled into crafting materials.',
#   'weightKg': 3.0,
#   'foundIn': 'Residential',
#   'imageFilename': 'https://cdn.arctracker.io/items/bicycle_pump.png',
#   'updatedAt': '11/01/2025',
#   'stackSize': 3},
#  {'id': 'broken_flashlight',
#   'name': 'Broken Flashlight',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': None,
#   'recyclesInto': {'battery': 2, 'metal_parts': 6},
#   'salvagesInto': {'metal_parts': 7},
#   'description': 'Can be recycled into crafting materials.',
#   'foundIn': 'Security',
#   'weightKg': 2.0,
#   'stackSize': 3,
#   'imageFilename': 'https://cdn.arctracker.io/items/broken_flashlight.png',
#   'updatedAt': '11/04/2025'},
#  {'id': 'broken_handheld_radio',
#   'name': 'Broken Handheld Radio',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 2000,
#   'recyclesInto': {'sensors': 3, 'wires': 2},
#   'updatedAt': '11/02/2025',
#   'description': 'Can be recycled into crafting materials.',
#   'weightKg': 3.0,
#   'stackSize': 3,
#   'foundIn': 'Security',
#   'imageFilename': 'https://cdn.arctracker.io/items/broken_handheld_radio.png'},
#  {'id': 'broken_riot_shield',
#   'name': 'Broken Riot Shield',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': None,
#   'recyclesInto': {'plastic_parts': 12},
#   'updatedAt': '10/30/2025'},
#  {'id': 'broken_taser',
#   'name': 'Broken Taser',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 1000,
#   'recyclesInto': {'battery': 2, 'wires': 2},
#   'weightKg': 2.0,
#   'stackSize': 3,
#   'foundIn': 'Security',
#   'updatedAt': '11/03/2025'},
#  {'id': 'cooling_coil',
#   'name': 'Cooling Coil',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 1000,
#   'recyclesInto': {'chemicals': 6, 'steel_spring': 2},
#   'description': 'Can be recycled into crafting materials.',
#   'weightKg': 2.0,
#   'foundIn': 'Industrial',
#   'imageFilename': 'https://cdn.arctracker.io/items/cooling_coil.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'cooling_fan',
#   'name': 'Cooling Fan',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 2000,
#   'recyclesInto': {'plastic_parts': 14, 'battery': 4},
#   'description': 'Can be recycled into crafting materials.',
#   'weightKg': 1.0,
#   'foundIn': 'Technological',
#   'imageFilename': 'https://cdn.arctracker.io/items/cooling_fan.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'cracked_bioscanner',
#   'name': 'Cracked Bioscanner',
#   'rarity': 'Rare',
#   'type': 'Recyclable',
#   'value': 640,
#   'recyclesInto': {'rubber_parts': 3, 'battery': 5},
#   'description': 'Can be recycled into crafting materials.',
#   'foundIn': 'Medical',
#   'imageFilename': 'https://cdn.arctracker.io/items/cracked_bioscanner.png',
#   'updatedAt': '10/30/2025'},
#  {'id': 'crude_explosives',
#   'name': 'Crude Explosives',
#   'description': "Used to craft explosives. Can be recycled into crafting materials. Used to craft: Launcher Ammo, Explosive Compound, Snap Blast Grenade, Shrapnel Grenade, Trigger 'Nade",
#   'rarity': 'Uncommon',
#   'type': 'Refined Material',
#   'value': 270,
#   'recyclesInto': {'chemicals': 3},
#   'salvagesInto': {'chemicals': 2},
#   'imageFilename': 'https://cdn.arctracker.io/items/crude_explosives.png',
#   'effects': {'Radius': '1.5m', 'Damage': 15},
#   'foundIn': 'Industrial, Security',
#   'weightKg': 0.5,
#   'updatedAt': '11/03/2025',
#   'stackSize': 10,
#   'recipe': {'chemicals': 6},
#   'craftBench': 'refiner'},
#  {'id': 'crumpled_plastic_bottle',
#   'name': 'Crumpled Plastic Bottle',
#   'rarity': 'Uncommon',
#   'weightKg': 0.8,
#   'stackSize': 3,
#   'foundIn': 'Residential',
#   'imageFilename': 'https://cdn.arctracker.io/items/crumpled_plastic_bottle.png',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'value': 270,
#   'recyclesInto': {'plastic_parts': 4},
#   'salvagesInto': {'plastic_parts': 1},
#   'updatedAt': '11/04/2025'},
#  {'id': 'garlic_press',
#   'name': 'Garlic Press',
#   'description': "It'll press garlic, olives, and probably many other things.",
#   'rarity': 'Uncommon',
#   'type': 'Recyclable',
#   'value': 1000,
#   'weightKg': 0.8,
#   'stackSize': 3,
#   'recyclesInto': {'metal_parts': 12},
#   'salvagesInto': {'metal_parts': 7},
#   'updatedAt': '11/04/2025',
#   'foundIn': 'Residential, Commercial'},
#  {'id': 'great_mullein',
#   'name': 'Great Mullein',
#   'rarity': 'Uncommon',
#   'type': 'Topside Material',
#   'value': 300,
#   'recyclesInto': {'assorted_seeds': 2},
#   'updatedAt': '10/31/2025',
#   'description': 'Used to craft medical supplies. Used to craft: Herbal Bandage, Antiseptic',
#   'weightKg': 0.25,
#   'foundIn': 'Nature',
#   'stackSize': 15,
# ...
#   'updatedAt': '11/03/2025',
#   'imageFilename': 'https://cdn.arctracker.io/items/bandage.png',
#   'recipe': {'fabric': 5},
#   'craftBench': ['workbench', 'med_station']},
#  {'id': 'tagging_grenade',
#   'name': 'Tagging Grenade',
#   'description': 'A grenade that detonates after a delay, tagging Raiders and ARC enemies in an area, allowing you to briefly track their location.',
#   'type': 'Quick Use',
#   'rarity': 'Rare',
#   'value': 1000,
#   'recyclesInto': {'plastic_parts': 1, 'sensors': 1},
#   'weightKg': 0.4,
#   'stackSize': 3,
#   'effects': {'Radius': '6m', 'Duration': '30s'},
#   'updatedAt': '11/03/2025'},
#  {'id': 'looting_mk1',
#   'name': 'Looting Mk. 1',
#   'description': 'Basic looting augment. More backpack slots and weight capacity, but low defensive and tactical capability.',
#   'type': 'Augment',
#   'rarity': 'Uncommon',
#   'value': 640,
#   'recyclesInto': {'rubber_parts': 3, 'plastic_parts': 3},
#   'weightKg': 1.0,
#   'effects': {'Durability': '100/100',
#    'Shield Compatibility': 'Light',
#    'Max Loadout Weight': 50.0},
#   'updatedAt': '11/03/2025',
#   'recipe': {'plastic_parts': 6, 'rubber_parts': 6},
#   'imageFilename': 'https://cdn.arctracker.io/items/looting_mk1.png',
#   'craftBench': ['equipment_bench', 'workbench']},
#  {'id': 'muzzle_brake_i',
#   'name': 'Muzzle Brake I',
#   'description': 'Slightly reduces both vertical recoil & horizontal recoil. Compatible with: Rattler, Ferro, Burletta, Stitcher, Tempest',
#   'type': 'Modification',
#   'rarity': 'Common',
#   'value': 640,
#   'recyclesInto': {'metal_parts': 5},
#   'weightKg': 0.25,
#   'effects': {'Reduced Horizontal Recoil': '15%',
#    'Reduced Vertical Recoil': '15%'},
#   'updatedAt': '11/03/2025',
#   'recipe': {'metal_parts': 6, 'wires': 1},
#   'craftBench': 'weapon_bench'},
#  {'id': 'rattler_i',
#   'name': 'Rattler I',
#   'description': 'A cheap offensive option, but has to be reloaded 2 bullets at a time.',
#   'type': 'Weapon',
#   'rarity': 'Common',
#   'value': 1750,
#   'recyclesInto': {'metal_parts': 8},
#   'weightKg': 6.0,
#   'effects': {'Durability': '100/100',
#    'ARC Armor Penetration': 'Moderate',
#    'Ammo Type': 'Medium Ammo',
#    'Firing Mode': 'Fully-Automatic',
#    'Magazine Size': 10},
#   'updatedAt': '11/04/2025',
#   'imageFilename': 'https://cdn.arctracker.io/items/rattler_i.png',
#   'recipe': {'metal_parts': 16, 'rubber_parts': 12},
#   'craftBench': 'weapon_bench'},
#  {'id': 'painted_box',
#   'name': 'Painted Box',
#   'description': 'May be worth a few coins.',
#   'type': 'Trinket',
#   'rarity': 'Uncommon',
#   'value': 2000,
#   'recyclesInto': {},
#   'weightKg': 0.3,
#   'stackSize': 3,
#   'foundIn': 'Old World',
#   'updatedAt': '11/03/2025',
#   'imageFilename': 'https://cdn.arctracker.io/items/painted_box.png'},
#  {'id': 'music_box',
#   'name': 'Music Box',
#   'description': 'Worth a small fortune.',
#   'type': 'Trinket',
#   'rarity': 'Rare',
#   'value': 5000,
#   'recyclesInto': {},
#   'weightKg': 0.4,
#   'stackSize': 3,
#   'foundIn': 'Old World, Residential, Commercial',
#   'updatedAt': '11/03/2025'},
#  {'id': 'hairpin_i',
#   'name': 'Hairpin I',
#   'description': 'Has a built-in silencer. Great for stealth, but tricky in combat.',
#   'type': 'Pistol',
#   'rarity': 'Common',
#   'effects': {'Durability': '100/100',
#    'Special Trait': 'Integrated Silencer',
#    'ARC Armor Penetration': 'Very Weak',
#    'Ammo Type': 'Light Ammo',
#    'Firing Mode': 'Slide-Action',
#    'Magazine Size': 8},
#   'weightKg': 3.0,
#   'value': 450,
#   'imageFilename': 'https://cdn.arctracker.io/items/hairpin_i.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'metal_parts': 2, 'plastic_parts': 5},
#   'craftBench': ['workbench', 'weapon_bench']},
#  {'id': 'looting_mk2',
#   'name': 'Looting Mk. 2',
#   'description': 'Significantly increases looting potential; adds slots for trinkets. Automatically throws off attached Ticks after 1s.',
#   'type': 'Augment',
#   'rarity': 'Rare',
#   'effects': {'Durability': '100/100',
#    'Shield Compatibility': 'Light',
#    'Max Loadout Weight': 60.0},
#   'weightKg': 2.0,
#   'value': 2000,
#   'imageFilename': 'https://cdn.arctracker.io/items/looting_mk2.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'electrical_components': 2, 'magnet': 3},
#   'craftBench': 'equipment_bench'},
#  {'id': 'looting_mk3_cautious',
#   'name': 'Looting Mk. 3 (Cautious)',
#   'description': 'A looting augment that swaps some carry capacity to increase survivability. Upon Shield break, automatically administers a weak Adrenaline Shot. Has a fixed cooldown.',
#   'type': 'Augment',
#   'rarity': 'Epic',
#   'value': 5000,
#   'weightKg': 3.0,
#   'effects': {'Durability': '100/100',
#    'Shield Compatibility': 'Light',
#    'Max Loadout Weight': 70.0},
#   'imageFilename': 'https://cdn.arctracker.io/items/looting_mk3_cautious.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'advanced_electrical_components': 2, 'processor': 3},
#   'craftBench': 'equipment_bench'},
#  {'id': 'angled_grip_i',
#   'name': 'Angled Grip I',
#   'description': 'Slightly reduces horizontal recoil. Compatible with: Tempest, Arpeggio, Kettle, Ferro, Hullcracker',
#   'type': 'Modification',
#   'rarity': 'Common',
#   'weightKg': 0.25,
#   'value': 640,
#   'effects': {'Reduced Horizontal Recoil': '20%'},
#   'imageFilename': 'https://cdn.arctracker.io/items/angled_grip_i.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'plastic_parts': 6, 'duct_tape': 1},
#   'craftBench': 'weapon_bench'},
#  {'id': 'extended_shotgun_mag_i',
#   'name': 'Extended Shotgun Mag I',
#   'description': 'Slightly extends the ammo capacity of shotguns. Compatible with: Il Toro, Vulcano',
#   'type': 'Modification',
#   'rarity': 'Common',
#   'weightKg': 0.25,
#   'value': 640,
#   'effects': {'Magazine Size': '+2'},
#   'imageFilename': 'https://cdn.arctracker.io/items/extended_shotgun_mag_i.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'plastic_parts': 6, 'steel_spring': 1},
#   'craftBench': 'weapon_bench'},
#  {'id': 'shotgun_choke_i',
#   'name': 'Shotgun Choke I',
#   'description': 'Slightly reduces base dispersion. Compatible with: Il Toro, Vulcano',
#   'type': 'Modification',
#   'rarity': 'Common',
#   'value': 640,
#   'weightKg': 0.25,
#   'effects': {'Reduced Base Dispersion': '10%'},
#   'imageFilename': 'https://cdn.arctracker.io/items/shotgun_choke_i.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'metal_parts': 6, 'wires': 1},
#   'craftBench': 'weapon_bench'},
#  {'id': 'vertical_grip_i',
#   'name': 'Vertical Grip I',
#   'description': 'Slightly reduces vertical recoil. Compatible with: Tempest, Arpeggio, Kettle, Ferro, Hullcracker',
#   'type': 'Modification',
#   'rarity': 'Common',
#   'weightKg': 0.25,
#   'value': 640,
#   'effects': {'Reduced Vertical Recoil': '20%'},
#   'imageFilename': 'https://cdn.arctracker.io/items/vertical_grip_i.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'plastic_parts': 6, 'duct_tape': 1},
#   'craftBench': 'weapon_bench'},
#  {'id': 'lightweight_stock',
#   'name': 'Lightweight Stock',
#   'description': 'Moderately improves ADS & draw speed. Compatible with: Arpeggio, Kettle, Ferro, Renegade, Hullcracker',
#   'type': 'Modification',
#   'value': 5000,
#   'rarity': 'Epic',
#   'weightKg': 0.25,
#   'effects': {'Increased ADS Speed': '200%',
#    'Increased Vertical Recoil': '50%',
#    'Reduced Equip Time': '30%',
#    'Reduced Unequip Time': '30%',
#    'Increased Recoil Recovery Time': '50%'},
#   'imageFilename': 'https://cdn.arctracker.io/items/lightweight_stock.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'mod_components': 2, 'duct_tape': 5},
#   'craftBench': 'weapon_bench'},
#  {'id': 'bettina_i',
#   'name': 'Bettina I',
#   'description': 'Has slow fire rate and high damage output.',
#   'type': 'Weapon',
#   'value': 8000,
#   'rarity': 'Epic',
#   'weightKg': 11.0,
#   'effects': {'Durability': '100/100',
#    'ARC Armor Penetration': 'Strong',
#    'Ammo Type': 'Heavy Ammo',
#    'Firing Mode': 'Fully-Automatic',
#    'Magazine Size': 20},
#   'imageFilename': 'https://cdn.arctracker.io/items/bettina.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'advanced_mechanical_components': 3,
#    'heavy_gun_parts': 3,
#    'canister': 3},
#   'craftBench': 'weapon_bench'},
#  {'id': 'launcher_ammo',
#   'name': 'Launcher Ammo',
#   'description': 'Anti-ARC payloads used mainly by the Hullcracker. Compatible with: Hullcracker',
#   'type': 'Ammunition',
#   'value': 10,
#   'rarity': 'Rare',
#   'weightKg': 0.1,
#   'stackSize': 24,
#   'imageFilename': 'https://cdn.arctracker.io/items/launcher_ammo.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'metal_parts': 5, 'crude_explosives': 1},
#   'craftBench': 'workbench'},
#  {'id': 'shotgun_ammo',
#   'name': 'Shotgun Ammo',
#   'description': 'Compatible with: Il Toro, Vulcano',
#   'type': 'Ammunition',
#   'value': 20,
#   'weightKg': 0.085,
#   'stackSize': 20,
#   'imageFilename': 'https://cdn.arctracker.io/items/shotgun_ammo.png',
#   'rarity': 'Common',
#   'updatedAt': '11/03/2025',
#   'recipe': {'metal_parts': 3, 'chemicals': 2},
#   'craftBench': 'workbench'},
#  {'id': 'torrente_blueprint',
#   'name': 'Torrente Blueprint',
#   'description': 'Has a large ammo capacity, but is only accurate while crouched.',
#   'type': 'Blueprint',
#   'weightKg': 0.0,
#   'rarity': 'Common',
#   'imageFilename': 'https://cdn.arctracker.io/items/torrente_blueprint.png',
#   'updatedAt': '11/03/2025',
#   'value': 5000},
#  {'id': 'anvil_blueprint',
#   'name': 'Anvil Blueprint',
#   'description': 'Has high damage output and headshot damage, but slow handling.',
#   'type': 'Blueprint',
#   'value': 5000,
#   'weightKg': 0.0,
#   'rarity': 'Common',
#   'imageFilename': 'https://cdn.arctracker.io/items/anvil_blueprint.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'anvil_i',
#   'name': 'Anvil I',
#   'description': 'Has high damage output and headshot damage, but slow handling.',
#   'type': 'Weapon',
#   'rarity': 'Uncommon',
#   'effects': {'Durability': '100/100',
#    'ARC Armor Penetration': 'Strong',
#    'Ammo Type': 'Heavy Ammo',
#    'Firing Mode': 'Single-Action',
#    'Magazine Size': 6},
#   'weightKg': 5.0,
#   'value': 5000,
#   'imageFilename': 'https://cdn.arctracker.io/items/anvil.png',
#   'updatedAt': '11/03/2025',
#   'recipe': {'mechanical_components': 5, 'simple_gun_parts': 6},
#   'craftBench': 'weapon_bench'},
#  {'id': 'osprey_blueprint',
#   'name': 'Osprey Blueprint',
#   'description': 'Has reliable damage output and accuracy.',
#   'type': 'Blueprint',
#   'value': 5000,
#   'weightKg': 0.0,
#   'rarity': 'Common',
#   'imageFilename': 'https://cdn.arctracker.io/items/osprey_blueprint.png',
#   'updatedAt': '11/03/2025'},
#  {'id': 'venator_blueprint',
#   'name': 'Venator Blueprint',
#   'description': 'Fires two shots at a time.',
#   'type': 'Blueprint',
#   'value': 5000,
#   'imageFilename': 'https://cdn.arctracker.io/items/venator.png',
#   'rarity': 'Common',
#   'updatedAt': '11/04/2025'},
#  {'id': 'extended_medium_mag_iii_blueprint',
#   'name': 'Extended Medium Mag III Blueprint',
#   'description': 'Significantly extends the ammo capacity of compataible weapons that use medium ammo.',
#   'type': 'Blueprint',
#   'effects': {'Magazine Size': '+12'},
#   'value': 5000,
#   'imageFilename': 'https://cdn.arctracker.io/items/extended_medium_mag_iii.png',
#   'rarity': 'Common',
#   'updatedAt': '11/04/2025'},
#  {'id': 'muzzle_brake_ii_blueprint',
#   'name': 'Muzzle Brake II Blueprint',
#   'description': 'Moderately reduces both vertical recoil & horizontal recoil.',
#   'effects': {'Reduced Horizontal Recoil': '20%',
#    'Reduced Vertical Recoil': '20%'},
#   'type': 'Blueprint',
#   'value': 5000,
#   'weightKg': 0.0,
#   'rarity': 'Common',
#   'station': 'weapon_bench',
#   'benchLevel': 2,
#   'crafting': {'mechanical_components': 2, 'wires': 4},
#   'imageFilename': 'https://cdn.arctracker.io/items/muzzle_brake_ii_blueprint.png',
#   'updatedAt': '11/05/2025'},
#  {'id': 'damaged_arc_powercell',
#   'name': 'Damaged ARC Powercell',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Common',
#   'value': 293,
#   'recyclesInto': {'arc_alloy': 1},
#   'weightKg': 0.25,
#   'stackSize': 5,
#   'foundIn': 'ARC',
#   'updatedAt': '11/05/2025'},
#  {'id': 'metal_brackets',
#   'name': 'Metal Brackets',
#   'description': 'Can be recycled into metal parts.',
#   'type': 'Recyclable',
#   'rarity': 'Uncommon',
#   'value': 640,
#   'recyclesInto': {'metal_parts': 8},
#   'salvagesInto': {'metal_parts': 4},
#   'weightKg': 0.8,
#   'stackSize': 3,
#   'foundIn': 'Mechanical, Electrical',
#   'updatedAt': '11/05/2025'},
#  {'id': 'vita_spray_blueprint',
#   'name': 'Vita Spray Blueprint',
#   'description': 'A medical item that continuously restores health during use. Can be used on yourself or your allies.',
#   'type': 'Blueprint',
#   'value': 5000,
#   'imageFilename': 'https://cdn.arctracker.io/items/vita_spray.png',
#   'rarity': 'Common',
#   'updatedAt': '11/04/2025'},
#  {'id': 'rosary',
#   'name': 'Rosary',
#   'description': 'May be worth a few coins.',
#   'type': 'Trinket',
#   'value': 2000,
#   'rarity': 'Rare',
#   'weightKg': 0.3,
#   'stackSize': 3,
#   'foundIn': 'Old World, Residential',
#   'imageFilename': 'https://cdn.arctracker.io/items/rosary.png',
#   'updatedAt': '11/04/2025'},
#  {'id': 'damaged_wasp_driver',
#   'name': 'Damaged Wasp Driver',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Common',
#   'weightKg': 0.25,
#   'value': 270,
#   'foundIn': 'ARC',
#   'imageFilename': 'https://cdn.arctracker.io/items/damaged_wasp_driver.png',
#   'updatedAt': '11/04/2025'},
#  {'id': 'ruined_parachute',
#   'name': 'Ruined Parachute',
#   'description': 'Can be recycled into crafting materials.',
#   'type': 'Recyclable',
#   'rarity': 'Uncommon',
#   'value': 640,
#   'weightKg': 0.8,
#   'stackSize': 3,
#   'foundIn': 'Exodus',
#   'imageFilename': 'https://cdn.arctracker.io/items/ruined_parachute.png',
#   'updatedAt': '11/04/2025'},
#  {'id': 'extended_shotgun_mag_ii_blueprint',
#   'name': 'Extended Shotgun Mag II Blueprint',
#   'description': 'Moderately extends the ammo capacity of shotguns.',
#   'type': 'Blueprint',
#   'value': 5000,
#   'recyclesInto': {'mechanical_components': 8, 'steel_spring': 28},
#   'rarity': 'Common',
#   'imageFilename': 'https://cdn.arctracker.io/items/extended_shotgun_mag_ii_blueprint.png',
#   'updatedAt': '11/04/2025'},
#  {'id': 'silencer_iii',
#   'name': 'Silencer III',
#   'description': 'Significantly reduces the amount of noise produced when firing. Compatible with: Tempest, Arpeggio, Kettle, Ferro, Renegade',
#   'type': 'Modification',
#   'rarity': 'Epic',
#   'value': 7000,
#   'weightKg': 0.75,
#   'compatibleWith': ['Arpeggio', 'Rattler', 'Ferro', 'Anvil', 'Torrente'],
#   'effects': {'Increased Durability Burn Rate': '20%', 'Reduced Noise': '60%'},
#   'recyclesInto': {'mod_components': 1, 'wires': 3},
#   'salvagesInto': {'mod_components': 1},
#   'craftBench': 'weapon_bench',
#   'benchLevel': 3,
#   'updatedAt': '11/05/2025',
#   'imageFilename': 'https://cdn.arctracker.io/items/silencer_iii.png'},
#  {'id': 'blue_light_stick_blueprint',
#   'name': 'Blue Light Stick Blueprint',
#   'description': 'A throwable chemical light that illuminates the area around it.',
#   'type': 'Blueprint',
#   'value': 5000,
#   'weightKg': 0,
#   'foundIn': '',
#   'imageFilename': 'https://cdn.arctracker.io/items/blue_light_stick_blueprint.png',
#   'rarity': 'Common',
#   'updatedAt': '11/04/2025'},
#  {'id': 'spaceport_control_tower_key',
#   'name': 'Spaceport Control Tower Key',
#   'description': 'Unlocks a door in Control Tower A6 in Spaceport',
#   'type': 'Key',
#   'value': 100,
#   'rarity': 'Rare',
#   'weightKg': 0.25,
#   'imageFilename': 'https://cdn.arctracker.io/items/spaceport_control_tower_key.png',
#   'updatedAt': '11/04/2025'},
#  {'id': 'extended_medium_mag_ii_blueprint',
#   'name': 'Extended Medium Mag II Blueprint',
#   'description': 'Moderately extends the ammo capacity of compatible weapons that use medium ammo.',
#   'type': 'Blueprint',
#   'value': 5000,
#   'weightKg': 0.0,
#   'imageFilename': 'https://cdn.arctracker.io/items/extended_medium_mag_ii_blueprint.png',
#   'rarity': 'Common',
#   'updatedAt': '11/04/2025'},
#  {'id': 'rosary',
#   'name': 'Rosary',
#   'description': 'May be worth a few coins.',
#   'type': 'Trinket',
#   'rarity': 'Rare',
#   'value': 2000,
#   'recyclesInto': {},
#   'weightKg': 0.3,
#   'stackSize': 3,
#   'foundIn': 'Old World, Residential',
#   'updatedAt': '11/05/2025'}]
